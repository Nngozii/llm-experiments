# %%
# Importing packages

import os
from IPython.display import Markdown, display, update_display
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
MISTRAL_BASE_URL = "https://api.mistral.ai/v1"
OLLAMA_BASE_URL = "http://localhost:11434/v1"
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

mistral_api_key = os.getenv('MISTRAL_API_KEY')
openai_api_key = os.getenv('OPENAI_API_KEY')
gemini_api_key = os.getenv('GOOGLE_API_KEY')

if mistral_api_key:
    print(f"Key found and begins with {mistral_api_key[:5]}")
else:
    print("key not found")
if openai_api_key:
    print(f"Key found and begins with {openai_api_key[:5]}")
else:
    print("key not found")
if gemini_api_key:
    print(f"Key found and begins with {gemini_api_key[:5]}")
else:
    print("key not found")
# Out:
# Key found and begins with PkEgS
# Key found and begins with sk-pr
# Key found and begins with AIzaS

# %%
mistral = OpenAI(base_url=MISTRAL_BASE_URL, api_key=mistral_api_key)
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=gemini_api_key)
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
